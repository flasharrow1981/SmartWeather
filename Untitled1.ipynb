# %%
# %load cut_area_by_point.py


# In[23]:


# %load test.py


# In[ ]:


from __future__ import print_function
import traceback
import sys
import glob
import os
 
from eccodes import *
 
INPUT = '/home/dp/data/ECMF_DAM/PUB/W_NAFP_C_ECMF_20171108054547_P_C1D11080000110800001'
STATIONINPUT='/home/dp/data/stationTest.txt'
VERBOSE = 1  # verbose error reporting
missingValue = 1e+20  # A value out of range 
eles=['10U','10V','2D','2T','CP','FAL','LCC','LSP','MSL','PWC','SD','SKT','TP','TCC','D','GH','Q','R','T','U','V','W']
                
 
def example():
    f = open(INPUT)
    
    for line in open(STATIONINPUT):
        lineSplit=line.split(" ")
        dateTime=lineSplit[0][4:]+lineSplit[1]+lineSplit[2]
        dateTime_2=dateTime+dateTime+"1"
        fileNameMatch=r"/home/dp/data/ECMF_DAM/PUB/W_NAFP_C_ECMF_*"+dateTime_2
        list=glob.glob(fileNameMatch)
        
        ww=lineSplit[5]
        trainfolder=r"/home/dp/data/taged_ecmf/"+ww#存放预报片段的文件夹，需和文件名间加入类型文件夹
        
        tagedfilename=trainfolder+"/ecmf"+dateTime #从数值预报中截取的所需预报片段文件名
        if not os.path.exists(trainfolder):
            os.makedirs(trainfolder)
        
        
        print(tagedfilename)
        
        print(list)#文件名列表
        
    
        for onefile in list:
            f=open(onefile)
            message_count=codes_count_in_file(f) #文件中共有多少message
            print("message count %d" % (message_count))
            
            output_file=open(tagedfilename,'wb+')
            
            
            
            #跳过的部分
            i=0
            while 1:
                gid = codes_grib_new_from_file(f)
                if gid is None:
                    break
                
                keyval = codes_get_string(gid, "shortName")
                #不在目录内则跳过
                if keyval.upper() not in eles:
                    continue
                
                i=i+1
                print("%s = %s" % ("keyname", keyval))
                keyval = codes_get_string(gid, "level")
                print("%s = %s" % ("level", keyval))
                
                
                values = codes_get_values(gid)
                print('len:%d' %(len(values)))


                lat=float(lineSplit[3])
                lon=float(lineSplit[4])
                #读取最近点的索引号
                nearest = codes_grib_find_nearest(gid, lat, lon)[0]
                print(nearest.lat, nearest.lon, nearest.value, nearest.distance,
                      nearest.index)


                #testnearest = codes_grib_find_nearest(gid,30,98.5)[0]
                #print(testnearest.lat, testnearest.lon, testnearest.value, testnearest.distance,
                #      testnearest.index)




                nearestIndex=nearest.index
                #数值预报范围,欧洲细网格实际为60～-10
                latRange=[-10,60]
                latdense=0.25
                latcount=(latRange[1]-latRange[0])/latdense+1

                lonRange=[60,150]
                londense=0.25
                loncount=(lonRange[1]-lonRange[0])/londense+1

                crange=9  #截取的范围大小
                radius=(crange-1)/2 #以中心点为核心上下左右各2 
                
                print("value test：%.10e"%values[nearest.index])
                keyval = codes_get_string(gid, "shortName")
                print("%s = %s" % ("keyname", keyval))
                keyval = codes_get_string(gid, "level")
                print("%s = %s" % ("level", keyval))
                
                
                
               

                #开始截取
                for r in range(-1*radius,radius+1):
                    cur_min=int(nearestIndex+r*loncount-radius)
                    cur_max=int(nearestIndex+r*loncount+radius)

                    #print(cur_min,cur_max)
                    curdata=values[cur_min:cur_max+1]
                    #print(curdata)
                    output_file.write(curdata)

                
                
                print("total elems and levels:%d"%i)
                print("-" * 100)
                
                
              
                
                
                
                
                
                
                codes_release(gid)  
                
            
            f.close()
            output_file.close()
            
 
 
 
def main():
    try:
        example()
    except CodesInternalError as err:
        if VERBOSE:
            traceback.print_exc(file=sys.stderr)
        else:
            sys.stderr.write(err.msg + '\n')
 
        return 1
 
 
if __name__ == "__main__":
    sys.exit(main())
# Out:
# /home/dp/data/taged_ecmf/25/ecmf11080000
# ['/home/dp/data/ECMF_DAM/PUB/W_NAFP_C_ECMF_20171108054547_P_C1D11080000110800001']
# message count 601
# keyname = q
# level = 250
# len:101441
# 29.75 98.5 2.25873463933e-05 14.7205308446 43835
# value test：2.2587346393e-05
# keyname = q
# level = 250
# total elems and levels:1
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 850
# len:101441
# 29.75 98.5 286.690261841 14.7205308446 43835
# value test：2.8669026184e+02
# keyname = t
# level = 850
# total elems and levels:2
# ----------------------------------------------------------------------------------------------------
# keyname = skt
# level = 0
# len:4150080
# 29.625 98.625 256.594299316 3.68111706585 1391829
# value test：2.5659429932e+02
# keyname = skt
# level = 0
# total elems and levels:3
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 20
# len:101441
# 29.75 98.5 2.77376511804e-06 14.7205308446 43835
# value test：2.7737651180e-06
# keyname = q
# level = 20
# total elems and levels:4
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 800
# len:101441
# 29.75 98.5 0.000184884993359 14.7205308446 43835
# value test：1.8488499336e-04
# keyname = d
# level = 800
# total elems and levels:5
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 800
# len:101441
# 29.75 98.5 2085.09277344 14.7205308446 43835
# value test：2.0850927734e+03
# keyname = gh
# level = 800
# total elems and levels:6
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 50
# len:101441
# 29.75 98.5 3.10161976813e-06 14.7205308446 43835
# value test：3.1016197681e-06
# keyname = q
# level = 50
# total elems and levels:7
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 50
# len:101441
# 29.75 98.5 20577.1757812 14.7205308446 43835
# value test：2.0577175781e+04
# keyname = gh
# level = 50
# total elems and levels:8
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 20
# len:101441
# 29.75 98.5 -0.000687420368195 14.7205308446 43835
# value test：-6.8742036819e-04
# keyname = w
# level = 20
# total elems and levels:9
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 800
# len:101441
# 29.75 98.5 60.7693009973 14.7205308446 43835
# value test：6.0769300997e+01
# keyname = r
# level = 800
# total elems and levels:10
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 70
# len:101441
# 29.75 98.5 2.39361858368 14.7205308446 43835
# value test：2.3936185837e+00
# keyname = v
# level = 70
# total elems and levels:11
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 70
# len:101441
# 29.75 98.5 15.6360168457 14.7205308446 43835
# value test：1.5636016846e+01
# keyname = u
# level = 70
# total elems and levels:12
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 850
# len:101441
# 29.75 98.5 0.000191976549104 14.7205308446 43835
# value test：1.9197654910e-04
# keyname = d
# level = 850
# total elems and levels:13
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 900
# len:101441
# 29.75 98.5 289.826873779 14.7205308446 43835
# value test：2.8982687378e+02
# keyname = t
# level = 900
# total elems and levels:14
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 900
# len:101441
# 29.75 98.5 0.00017876457423 14.7205308446 43835
# value test：1.7876457423e-04
# keyname = d
# level = 900
# total elems and levels:15
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 20
# len:101441
# 29.75 98.5 -3.622751683e-05 14.7205308446 43835
# value test：-3.6227516830e-05
# keyname = d
# level = 20
# total elems and levels:16
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 150
# len:101441
# 29.75 98.5 3.73016428057e-06 14.7205308446 43835
# value test：3.7301642806e-06
# keyname = q
# level = 150
# total elems and levels:17
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 600
# len:101441
# 29.75 98.5 0.00183177994319 14.7205308446 43835
# value test：1.8317799432e-03
# keyname = q
# level = 600
# total elems and levels:18
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 925
# len:101441
# 29.75 98.5 0.00017569353804 14.7205308446 43835
# value test：1.7569353804e-04
# keyname = d
# level = 925
# total elems and levels:19
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 600
# len:101441
# 29.75 98.5 -0.000213623046875 14.7205308446 43835
# value test：-2.1362304688e-04
# keyname = w
# level = 600
# total elems and levels:20
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 600
# len:101441
# 29.75 98.5 -8.85515473783e-05 14.7205308446 43835
# value test：-8.8551547378e-05
# keyname = d
# level = 600
# total elems and levels:21
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 950
# len:101441
# 29.75 98.5 0.000172686995938 14.7205308446 43835
# value test：1.7268699594e-04
# keyname = d
# level = 950
# total elems and levels:22
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 600
# len:101441
# 29.75 98.5 4393.61621094 14.7205308446 43835
# value test：4.3936162109e+03
# keyname = gh
# level = 600
# total elems and levels:23
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 200
# len:101441
# 29.75 98.5 222.004989624 14.7205308446 43835
# value test：2.2200498962e+02
# keyname = t
# level = 200
# total elems and levels:24
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 1000
# len:101441
# 29.75 98.5 0.000174488406628 14.7205308446 43835
# value test：1.7448840663e-04
# keyname = d
# level = 1000
# total elems and levels:25
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 200
# len:101441
# 29.75 98.5 14.7202606201 14.7205308446 43835
# value test：1.4720260620e+01
# keyname = v
# level = 200
# total elems and levels:26
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 200
# len:101441
# 29.75 98.5 40.5708312988 14.7205308446 43835
# value test：4.0570831299e+01
# keyname = u
# level = 200
# total elems and levels:27
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 250
# len:101441
# 29.75 98.5 9.84217834473 14.7205308446 43835
# value test：9.8421783447e+00
# keyname = v
# level = 250
# total elems and levels:28
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 250
# len:101441
# 29.75 98.5 34.3782196045 14.7205308446 43835
# value test：3.4378219604e+01
# keyname = u
# level = 250
# total elems and levels:29
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 10
# len:101441
# 29.75 98.5 -4.24548052251e-05 14.7205308446 43835
# value test：-4.2454805225e-05
# keyname = d
# level = 10
# total elems and levels:30
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 200
# len:101441
# 29.75 98.5 9.5748791864e-06 14.7205308446 43835
# value test：9.5748791864e-06
# keyname = q
# level = 200
# total elems and levels:31
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 10
# len:101441
# 29.75 98.5 30903.8164062 14.7205308446 43835
# value test：3.0903816406e+04
# keyname = gh
# level = 10
# total elems and levels:32
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 700
# len:101441
# 29.75 98.5 276.29914856 14.7205308446 43835
# value test：2.7629914856e+02
# keyname = t
# level = 700
# total elems and levels:33
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 10
# len:101441
# 29.75 98.5 0.0782499723136 14.7205308446 43835
# value test：7.8249972314e-02
# keyname = r
# level = 10
# total elems and levels:34
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 200
# len:101441
# 29.75 98.5 0.167128562927 14.7205308446 43835
# value test：1.6712856293e-01
# keyname = w
# level = 200
# total elems and levels:35
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 200
# len:101441
# 29.75 98.5 2.50632874668e-05 14.7205308446 43835
# value test：2.5063287467e-05
# keyname = d
# level = 200
# total elems and levels:36
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 200
# len:101441
# 29.75 98.5 12215.3320312 14.7205308446 43835
# value test：1.2215332031e+04
# keyname = gh
# level = 200
# total elems and levels:37
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 20
# len:101441
# 29.75 98.5 221.712036133 14.7205308446 43835
# value test：2.2171203613e+02
# keyname = t
# level = 20
# total elems and levels:38
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 800
# len:101441
# 29.75 98.5 283.406326294 14.7205308446 43835
# value test：2.8340632629e+02
# keyname = t
# level = 800
# total elems and levels:39
# ----------------------------------------------------------------------------------------------------
# keyname = 10v
# level = 0
# len:4150080
# 29.625 98.625 2.93533325195 3.68111706585 1391829
# value test：2.9353332520e+00
# keyname = 10v
# level = 0
# total elems and levels:40
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 20
# len:101441
# 29.75 98.5 4.3265838623 14.7205308446 43835
# value test：4.3265838623e+00
# keyname = v
# level = 20
# total elems and levels:41
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 20
# len:101441
# 29.75 98.5 7.53193664551 14.7205308446 43835
# value test：7.5319366455e+00
# keyname = u
# level = 20
# total elems and levels:42
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 800
# len:101441
# 29.75 98.5 0.0474243164062 14.7205308446 43835
# value test：4.7424316406e-02
# keyname = w
# level = 800
# total elems and levels:43
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 10
# len:101441
# 29.75 98.5 225.647216797 14.7205308446 43835
# value test：2.2564721680e+02
# keyname = t
# level = 10
# total elems and levels:44
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 850
# len:101441
# 29.75 98.5 60.6841402054 14.7205308446 43835
# value test：6.0684140205e+01
# keyname = r
# level = 850
# total elems and levels:45
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 400
# len:101441
# 29.75 98.5 1.688930206e-05 14.7205308446 43835
# value test：1.6889302060e-05
# keyname = d
# level = 400
# total elems and levels:46
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 20
# len:101441
# 29.75 98.5 0.279102683067 14.7205308446 43835
# value test：2.7910268307e-01
# keyname = r
# level = 20
# total elems and levels:47
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 700
# len:101441
# 29.75 98.5 -0.00912475585938 14.7205308446 43835
# value test：-9.1247558594e-03
# keyname = v
# level = 700
# total elems and levels:48
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 700
# len:101441
# 29.75 98.5 0.0660095214844 14.7205308446 43835
# value test：6.6009521484e-02
# keyname = u
# level = 700
# total elems and levels:49
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 70
# len:101441
# 29.75 98.5 3.09245751851e-06 14.7205308446 43835
# value test：3.0924575185e-06
# keyname = q
# level = 70
# total elems and levels:50
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 600
# len:101441
# 29.75 98.5 268.399047852 14.7205308446 43835
# value test：2.6839904785e+02
# keyname = t
# level = 600
# total elems and levels:51
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 50
# len:101441
# 29.75 98.5 210.767181396 14.7205308446 43835
# value test：2.1076718140e+02
# keyname = t
# level = 50
# total elems and levels:52
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 950
# len:101441
# 29.75 98.5 0.00100708007812 14.7205308446 43835
# value test：1.0070800781e-03
# keyname = v
# level = 950
# total elems and levels:53
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 950
# len:101441
# 29.75 98.5 0.0435180664062 14.7205308446 43835
# value test：4.3518066406e-02
# keyname = u
# level = 950
# total elems and levels:54
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 900
# len:101441
# 29.75 98.5 0.0677337646484 14.7205308446 43835
# value test：6.7733764648e-02
# keyname = v
# level = 900
# total elems and levels:55
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 900
# len:101441
# 29.75 98.5 0.0475463867188 14.7205308446 43835
# value test：4.7546386719e-02
# keyname = u
# level = 900
# total elems and levels:56
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 850
# len:101441
# 29.75 98.5 0.0308799743652 14.7205308446 43835
# value test：3.0879974365e-02
# keyname = w
# level = 850
# total elems and levels:57
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 50
# len:101441
# 29.75 98.5 1.83618164062 14.7205308446 43835
# value test：1.8361816406e+00
# keyname = v
# level = 50
# total elems and levels:58
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 50
# len:101441
# 29.75 98.5 6.75056648254 14.7205308446 43835
# value test：6.7505664825e+00
# keyname = u
# level = 50
# total elems and levels:59
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 250
# len:101441
# 29.75 98.5 10745.0976562 14.7205308446 43835
# value test：1.0745097656e+04
# keyname = gh
# level = 250
# total elems and levels:60
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 1000
# len:101441
# 29.75 98.5 225.727890015 14.7205308446 43835
# value test：2.2572789001e+02
# keyname = gh
# level = 1000
# total elems and levels:61
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 150
# len:101441
# 29.75 98.5 9.66107845306 14.7205308446 43835
# value test：9.6610784531e+00
# keyname = r
# level = 150
# total elems and levels:62
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 850
# len:101441
# 29.75 98.5 0.00187245360576 14.7205308446 43835
# value test：1.8724536058e-03
# keyname = q
# level = 850
# total elems and levels:63
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 1000
# len:101441
# 29.75 98.5 0.0288352966309 14.7205308446 43835
# value test：2.8835296631e-02
# keyname = w
# level = 1000
# total elems and levels:64
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 150
# len:101441
# 29.75 98.5 10.7916717529 14.7205308446 43835
# value test：1.0791671753e+01
# keyname = v
# level = 150
# total elems and levels:65
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 150
# len:101441
# 29.75 98.5 40.3626861572 14.7205308446 43835
# value test：4.0362686157e+01
# keyname = u
# level = 150
# total elems and levels:66
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 400
# len:101441
# 29.75 98.5 -4.27682495117 14.7205308446 43835
# value test：-4.2768249512e+00
# keyname = v
# level = 400
# total elems and levels:67
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 400
# len:101441
# 29.75 98.5 12.5008850098 14.7205308446 43835
# value test：1.2500885010e+01
# keyname = u
# level = 400
# total elems and levels:68
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 250
# len:101441
# 29.75 98.5 227.989303589 14.7205308446 43835
# value test：2.2798930359e+02
# keyname = t
# level = 250
# total elems and levels:69
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 950
# len:101441
# 29.75 98.5 0.0339689254761 14.7205308446 43835
# value test：3.3968925476e-02
# keyname = w
# level = 950
# total elems and levels:70
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 100
# len:101441
# 29.75 98.5 -0.000137469498441 14.7205308446 43835
# value test：-1.3746949844e-04
# keyname = d
# level = 100
# total elems and levels:71
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 700
# len:101441
# 29.75 98.5 0.105453491211 14.7205308446 43835
# value test：1.0545349121e-01
# keyname = w
# level = 700
# total elems and levels:72
# ----------------------------------------------------------------------------------------------------
# keyname = tcc
# level = 0
# len:4150080
# 29.625 98.625 0.0 3.68111706585 1391829
# value test：0.0000000000e+00
# keyname = tcc
# level = 0
# total elems and levels:73
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 700
# len:101441
# 29.75 98.5 60.5 14.7205308446 43835
# value test：6.0500000000e+01
# keyname = r
# level = 700
# total elems and levels:74
# ----------------------------------------------------------------------------------------------------
# keyname = lcc
# level = 0
# len:4150080
# 29.625 98.625 0.0 3.68111706585 1391829
# value test：0.0000000000e+00
# keyname = lcc
# level = 0
# total elems and levels:75
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 900
# len:101441
# 29.75 98.5 1111.22802734 14.7205308446 43835
# value test：1.1112280273e+03
# keyname = gh
# level = 900
# total elems and levels:76
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 300
# len:101441
# 29.75 98.5 9514.4296875 14.7205308446 43835
# value test：9.5144296875e+03
# keyname = gh
# level = 300
# total elems and levels:77
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 700
# len:101441
# 29.75 98.5 0.00187036226998 14.7205308446 43835
# value test：1.8703622700e-03
# keyname = q
# level = 700
# total elems and levels:78
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 925
# len:101441
# 29.75 98.5 0.00966835021973 14.7205308446 43835
# value test：9.6683502197e-03
# keyname = w
# level = 925
# total elems and levels:79
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 100
# len:101441
# 29.75 98.5 16486.8320312 14.7205308446 43835
# value test：1.6486832031e+04
# keyname = gh
# level = 100
# total elems and levels:80
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 150
# len:101441
# 29.75 98.5 0.384213447571 14.7205308446 43835
# value test：3.8421344757e-01
# keyname = w
# level = 150
# total elems and levels:81
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 300
# len:101441
# 29.75 98.5 23.5 14.7205308446 43835
# value test：2.3500000000e+01
# keyname = r
# level = 300
# total elems and levels:82
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 700
# len:101441
# 29.75 98.5 0.000184254022315 14.7205308446 43835
# value test：1.8425402232e-04
# keyname = d
# level = 700
# total elems and levels:83
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 700
# len:101441
# 29.75 98.5 3168.93652344 14.7205308446 43835
# value test：3.1689365234e+03
# keyname = gh
# level = 700
# total elems and levels:84
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 400
# len:101441
# 29.75 98.5 0.000496204802516 14.7205308446 43835
# value test：4.9620480252e-04
# keyname = q
# level = 400
# total elems and levels:85
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 70
# len:101441
# 29.75 98.5 -0.0422582626343 14.7205308446 43835
# value test：-4.2258262634e-02
# keyname = w
# level = 70
# total elems and levels:86
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 925
# len:101441
# 29.75 98.5 60.6906375885 14.7205308446 43835
# value test：6.0690637589e+01
# keyname = r
# level = 925
# total elems and levels:87
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 50
# len:101441
# 29.75 98.5 3.20358073711 14.7205308446 43835
# value test：3.2035807371e+00
# keyname = r
# level = 50
# total elems and levels:88
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 600
# len:101441
# 29.75 98.5 2.93998718262 14.7205308446 43835
# value test：2.9399871826e+00
# keyname = v
# level = 600
# total elems and levels:89
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 600
# len:101441
# 29.75 98.5 -0.320892333984 14.7205308446 43835
# value test：-3.2089233398e-01
# keyname = u
# level = 600
# total elems and levels:90
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 100
# len:101441
# 29.75 98.5 0.145029067993 14.7205308446 43835
# value test：1.4502906799e-01
# keyname = w
# level = 100
# total elems and levels:91
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 925
# len:101441
# 29.75 98.5 0.00186678860337 14.7205308446 43835
# value test：1.8667886034e-03
# keyname = q
# level = 925
# total elems and levels:92
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 100
# len:101441
# 29.75 98.5 5.06390380859 14.7205308446 43835
# value test：5.0639038086e+00
# keyname = v
# level = 100
# total elems and levels:93
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 100
# len:101441
# 29.75 98.5 27.6960754395 14.7205308446 43835
# value test：2.7696075439e+01
# keyname = u
# level = 100
# total elems and levels:94
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 70
# len:101441
# 29.75 98.5 4.81579918414e-05 14.7205308446 43835
# value test：4.8157991841e-05
# keyname = d
# level = 70
# total elems and levels:95
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 500
# len:101441
# 29.75 98.5 5810.0078125 14.7205308446 43835
# value test：5.8100078125e+03
# keyname = gh
# level = 500
# total elems and levels:96
# ----------------------------------------------------------------------------------------------------
# keyname = 10u
# level = 0
# len:4150080
# 29.625 98.625 -1.16819763184 3.68111706585 1391829
# value test：-1.1681976318e+00
# keyname = 10u
# level = 0
# total elems and levels:97
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 600
# len:101441
# 29.75 98.5 40.0 14.7205308446 43835
# value test：4.0000000000e+01
# keyname = r
# level = 600
# total elems and levels:98
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 950
# len:101441
# 29.75 98.5 60.742099762 14.7205308446 43835
# value test：6.0742099762e+01
# keyname = r
# level = 950
# total elems and levels:99
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 250
# len:101441
# 29.75 98.5 13.0 14.7205308446 43835
# value test：1.3000000000e+01
# keyname = r
# level = 250
# total elems and levels:100
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 1000
# len:101441
# 29.75 98.5 0.0142364501953 14.7205308446 43835
# value test：1.4236450195e-02
# keyname = v
# level = 1000
# total elems and levels:101
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 1000
# len:101441
# 29.75 98.5 0.0319862365723 14.7205308446 43835
# value test：3.1986236572e-02
# keyname = u
# level = 1000
# total elems and levels:102
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 10
# len:101441
# 29.75 98.5 -0.00104683637619 14.7205308446 43835
# value test：-1.0468363762e-03
# keyname = w
# level = 10
# total elems and levels:103
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 500
# len:101441
# 29.75 98.5 3.24011230469 14.7205308446 43835
# value test：3.2401123047e+00
# keyname = v
# level = 500
# total elems and levels:104
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 500
# len:101441
# 29.75 98.5 11.683303833 14.7205308446 43835
# value test：1.1683303833e+01
# keyname = u
# level = 500
# total elems and levels:105
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 70
# len:101441
# 29.75 98.5 18554.8984375 14.7205308446 43835
# value test：1.8554898438e+04
# keyname = gh
# level = 70
# total elems and levels:106
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 800
# len:101441
# 29.75 98.5 0.0503845214844 14.7205308446 43835
# value test：5.0384521484e-02
# keyname = v
# level = 800
# total elems and levels:107
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 800
# len:101441
# 29.75 98.5 0.121215820312 14.7205308446 43835
# value test：1.2121582031e-01
# keyname = u
# level = 800
# total elems and levels:108
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 900
# len:101441
# 29.75 98.5 0.00186699116603 14.7205308446 43835
# value test：1.8669911660e-03
# keyname = q
# level = 900
# total elems and levels:109
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 100
# len:101441
# 29.75 98.5 30.4730644226 14.7205308446 43835
# value test：3.0473064423e+01
# keyname = r
# level = 100
# total elems and levels:110
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 950
# len:101441
# 29.75 98.5 658.473632812 14.7205308446 43835
# value test：6.5847363281e+02
# keyname = gh
# level = 950
# total elems and levels:111
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 50
# len:101441
# 29.75 98.5 -9.38228331506e-05 14.7205308446 43835
# value test：-9.3822833151e-05
# keyname = d
# level = 50
# total elems and levels:112
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 400
# len:101441
# 29.75 98.5 7484.8828125 14.7205308446 43835
# value test：7.4848828125e+03
# keyname = gh
# level = 400
# total elems and levels:113
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 500
# len:101441
# 29.75 98.5 0.000568519101819 14.7205308446 43835
# value test：5.6851910182e-04
# keyname = q
# level = 500
# total elems and levels:114
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 850
# len:101441
# 29.75 98.5 1585.93164062 14.7205308446 43835
# value test：1.5859316406e+03
# keyname = gh
# level = 850
# total elems and levels:115
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 70
# len:101441
# 29.75 98.5 24.2732697129 14.7205308446 43835
# value test：2.4273269713e+01
# keyname = r
# level = 70
# total elems and levels:116
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 100
# len:101441
# 29.75 98.5 3.14237513521e-06 14.7205308446 43835
# value test：3.1423751352e-06
# keyname = q
# level = 100
# total elems and levels:117
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 500
# len:101441
# 29.75 98.5 0.0914459228516 14.7205308446 43835
# value test：9.1445922852e-02
# keyname = w
# level = 500
# total elems and levels:118
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 50
# len:101441
# 29.75 98.5 -0.00773012638092 14.7205308446 43835
# value test：-7.7301263809e-03
# keyname = w
# level = 50
# total elems and levels:119
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 900
# len:101441
# 29.75 98.5 60.6800880432 14.7205308446 43835
# value test：6.0680088043e+01
# keyname = r
# level = 900
# total elems and levels:120
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 100
# len:101441
# 29.75 98.5 200.178207397 14.7205308446 43835
# value test：2.0017820740e+02
# keyname = t
# level = 100
# total elems and levels:121
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 1000
# len:101441
# 29.75 98.5 295.638748169 14.7205308446 43835
# value test：2.9563874817e+02
# keyname = t
# level = 1000
# total elems and levels:122
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 250
# len:101441
# 29.75 98.5 0.191221237183 14.7205308446 43835
# value test：1.9122123718e-01
# keyname = w
# level = 250
# total elems and levels:123
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 1000
# len:101441
# 29.75 98.5 60.6281862259 14.7205308446 43835
# value test：6.0628186226e+01
# keyname = r
# level = 1000
# total elems and levels:124
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 500
# len:101441
# 29.75 98.5 19.0 14.7205308446 43835
# value test：1.9000000000e+01
# keyname = r
# level = 500
# total elems and levels:125
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 150
# len:101441
# 29.75 98.5 212.050979614 14.7205308446 43835
# value test：2.1205097961e+02
# keyname = t
# level = 150
# total elems and levels:126
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 10
# len:101441
# 29.75 98.5 2.73723890132e-06 14.7205308446 43835
# value test：2.7372389013e-06
# keyname = q
# level = 10
# total elems and levels:127
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 800
# len:101441
# 29.75 98.5 0.00187204135455 14.7205308446 43835
# value test：1.8720413545e-03
# keyname = q
# level = 800
# total elems and levels:128
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 400
# len:101441
# 29.75 98.5 43.0 14.7205308446 43835
# value test：4.3000000000e+01
# keyname = r
# level = 400
# total elems and levels:129
# ----------------------------------------------------------------------------------------------------
# keyname = sd
# level = 0
# len:4150080
# 29.625 98.625 0.00830078125 3.68111706585 1391829
# value test：8.3007812500e-03
# keyname = sd
# level = 0
# total elems and levels:130
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 900
# len:101441
# 29.75 98.5 0.0110549926758 14.7205308446 43835
# value test：1.1054992676e-02
# keyname = w
# level = 900
# total elems and levels:131
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 300
# len:101441
# 29.75 98.5 -1.73193359375 14.7205308446 43835
# value test：-1.7319335938e+00
# keyname = v
# level = 300
# total elems and levels:132
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 300
# len:101441
# 29.75 98.5 24.490524292 14.7205308446 43835
# value test：2.4490524292e+01
# keyname = u
# level = 300
# total elems and levels:133
# ----------------------------------------------------------------------------------------------------
# keyname = 2d
# level = 0
# len:4150080
# 29.625 98.625 259.002075195 3.68111706585 1391829
# value test：2.5900207520e+02
# keyname = 2d
# level = 0
# total elems and levels:134
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 70
# len:101441
# 29.75 98.5 199.268112183 14.7205308446 43835
# value test：1.9926811218e+02
# keyname = t
# level = 70
# total elems and levels:135
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 950
# len:101441
# 29.75 98.5 292.825057983 14.7205308446 43835
# value test：2.9282505798e+02
# keyname = t
# level = 950
# total elems and levels:136
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 300
# len:101441
# 29.75 98.5 1.96360051632e-05 14.7205308446 43835
# value test：1.9636005163e-05
# keyname = d
# level = 300
# total elems and levels:137
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 300
# len:101441
# 29.75 98.5 0.355668067932 14.7205308446 43835
# value test：3.5566806793e-01
# keyname = w
# level = 300
# total elems and levels:138
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 300
# len:101441
# 29.75 98.5 6.62996790197e-05 14.7205308446 43835
# value test：6.6299679020e-05
# keyname = q
# level = 300
# total elems and levels:139
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 925
# len:101441
# 29.75 98.5 882.204833984 14.7205308446 43835
# value test：8.8220483398e+02
# keyname = gh
# level = 925
# total elems and levels:140
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 1000
# len:101441
# 29.75 98.5 0.00187281961553 14.7205308446 43835
# value test：1.8728196155e-03
# keyname = q
# level = 1000
# total elems and levels:141
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 400
# len:101441
# 29.75 98.5 249.683883667 14.7205308446 43835
# value test：2.4968388367e+02
# keyname = t
# level = 400
# total elems and levels:142
# ----------------------------------------------------------------------------------------------------
# keyname = 2t
# level = 0
# len:4150080
# 29.625 98.625 267.131027222 3.68111706585 1391829
# value test：2.6713102722e+02
# keyname = 2t
# level = 0
# total elems and levels:143
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 20
# len:101441
# 29.75 98.5 26379.625 14.7205308446 43835
# value test：2.6379625000e+04
# keyname = gh
# level = 20
# total elems and levels:144
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 400
# len:101441
# 29.75 98.5 0.359268188477 14.7205308446 43835
# value test：3.5926818848e-01
# keyname = w
# level = 400
# total elems and levels:145
# ----------------------------------------------------------------------------------------------------
# keyname = msl
# level = 0
# len:4150080
# 29.625 98.625 102609.5625 3.68111706585 1391829
# value test：1.0260956250e+05
# keyname = msl
# level = 0
# total elems and levels:146
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 200
# len:101441
# 29.75 98.5 8.96112155914 14.7205308446 43835
# value test：8.9611215591e+00
# keyname = r
# level = 200
# total elems and levels:147
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 250
# len:101441
# 29.75 98.5 -2.63664405793e-05 14.7205308446 43835
# value test：-2.6366440579e-05
# keyname = d
# level = 250
# total elems and levels:148
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 925
# len:101441
# 29.75 98.5 291.328231812 14.7205308446 43835
# value test：2.9132823181e+02
# keyname = t
# level = 925
# total elems and levels:149
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 850
# len:101441
# 29.75 98.5 0.0643310546875 14.7205308446 43835
# value test：6.4331054688e-02
# keyname = v
# level = 850
# total elems and levels:150
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 850
# len:101441
# 29.75 98.5 0.0857849121094 14.7205308446 43835
# value test：8.5784912109e-02
# keyname = u
# level = 850
# total elems and levels:151
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 500
# len:101441
# 29.75 98.5 261.773223877 14.7205308446 43835
# value test：2.6177322388e+02
# keyname = t
# level = 500
# total elems and levels:152
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 10
# len:101441
# 29.75 98.5 3.54797363281 14.7205308446 43835
# value test：3.5479736328e+00
# keyname = v
# level = 10
# total elems and levels:153
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 10
# len:101441
# 29.75 98.5 10.1222381592 14.7205308446 43835
# value test：1.0122238159e+01
# keyname = u
# level = 10
# total elems and levels:154
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 950
# len:101441
# 29.75 98.5 0.00187281961553 14.7205308446 43835
# value test：1.8728196155e-03
# keyname = q
# level = 950
# total elems and levels:155
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 300
# len:101441
# 29.75 98.5 233.746932983 14.7205308446 43835
# value test：2.3374693298e+02
# keyname = t
# level = 300
# total elems and levels:156
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 150
# len:101441
# 29.75 98.5 14045.1289062 14.7205308446 43835
# value test：1.4045128906e+04
# keyname = gh
# level = 150
# total elems and levels:157
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 150
# len:101441
# 29.75 98.5 2.48074065894e-05 14.7205308446 43835
# value test：2.4807406589e-05
# keyname = d
# level = 150
# total elems and levels:158
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 500
# len:101441
# 29.75 98.5 6.77618663758e-05 14.7205308446 43835
# value test：6.7761866376e-05
# keyname = d
# level = 500
# total elems and levels:159
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 925
# len:101441
# 29.75 98.5 0.0361175537109 14.7205308446 43835
# value test：3.6117553711e-02
# keyname = v
# level = 925
# total elems and levels:160
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 925
# len:101441
# 29.75 98.5 0.0425720214844 14.7205308446 43835
# value test：4.2572021484e-02
# keyname = u
# level = 925
# total elems and levels:161
# ----------------------------------------------------------------------------------------------------
# /home/dp/data/taged_ecmf/10/ecmf11080000
# ['/home/dp/data/ECMF_DAM/PUB/W_NAFP_C_ECMF_20171108054547_P_C1D11080000110800001']
# message count 601
# keyname = q
# level = 250
# len:101441
# 40.0 124.25 1.35274403874e-05 12.5557874325 29137
# value test：1.3527440387e-05
# keyname = q
# level = 250
# total elems and levels:1
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 850
# len:101441
# 40.0 124.25 271.409011841 12.5557874325 29137
# value test：2.7140901184e+02
# keyname = t
# level = 850
# total elems and levels:2
# ----------------------------------------------------------------------------------------------------
# keyname = skt
# level = 0
# len:4150080
# 39.875 124.125 280.031799316 5.13128153418 1155873
# value test：2.8003179932e+02
# keyname = skt
# level = 0
# total elems and levels:3
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 20
# len:101441
# 40.0 124.25 2.74768808595e-06 12.5557874325 29137
# value test：2.7476880859e-06
# keyname = q
# level = 20
# total elems and levels:4
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 800
# len:101441
# 40.0 124.25 5.63177745789e-05 12.5557874325 29137
# value test：5.6317774579e-05
# keyname = d
# level = 800
# total elems and levels:5
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 800
# len:101441
# 40.0 124.25 1973.96777344 12.5557874325 29137
# value test：1.9739677734e+03
# keyname = gh
# level = 800
# total elems and levels:6
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 50
# len:101441
# 40.0 124.25 2.99428484141e-06 12.5557874325 29137
# value test：2.9942848414e-06
# keyname = q
# level = 50
# total elems and levels:7
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 50
# len:101441
# 40.0 124.25 20496.4257812 12.5557874325 29137
# value test：2.0496425781e+04
# keyname = gh
# level = 50
# total elems and levels:8
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 20
# len:101441
# 40.0 124.25 -0.0156334042549 12.5557874325 29137
# value test：-1.5633404255e-02
# keyname = w
# level = 20
# total elems and levels:9
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 800
# len:101441
# 40.0 124.25 18.2693009973 12.5557874325 29137
# value test：1.8269300997e+01
# keyname = r
# level = 800
# total elems and levels:10
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 70
# len:101441
# 40.0 124.25 5.67486858368 12.5557874325 29137
# value test：5.6748685837e+00
# keyname = v
# level = 70
# total elems and levels:11
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 70
# len:101441
# 40.0 124.25 18.6360168457 12.5557874325 29137
# value test：1.8636016846e+01
# keyname = u
# level = 70
# total elems and levels:12
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 850
# len:101441
# 40.0 124.25 -2.00371723622e-05 12.5557874325 29137
# value test：-2.0037172362e-05
# keyname = d
# level = 850
# total elems and levels:13
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 900
# len:101441
# 40.0 124.25 273.279998779 12.5557874325 29137
# value test：2.7327999878e+02
# keyname = t
# level = 900
# total elems and levels:14
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 900
# len:101441
# 40.0 124.25 -8.99331644177e-05 12.5557874325 29137
# value test：-8.9933164418e-05
# keyname = d
# level = 900
# total elems and levels:15
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 20
# len:101441
# 40.0 124.25 0.000122648663819 12.5557874325 29137
# value test：1.2264866382e-04
# keyname = d
# level = 20
# total elems and levels:16
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 150
# len:101441
# 40.0 124.25 3.93132995669e-06 12.5557874325 29137
# value test：3.9313299567e-06
# keyname = q
# level = 150
# total elems and levels:17
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 600
# len:101441
# 40.0 124.25 9.6092687329e-05 12.5557874325 29137
# value test：9.6092687329e-05
# keyname = q
# level = 600
# total elems and levels:18
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 925
# len:101441
# 40.0 124.25 -7.28578306735e-05 12.5557874325 29137
# value test：-7.2857830673e-05
# keyname = d
# level = 925
# total elems and levels:19
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 600
# len:101441
# 40.0 124.25 0.376251220703 12.5557874325 29137
# value test：3.7625122070e-01
# keyname = w
# level = 600
# total elems and levels:20
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 600
# len:101441
# 40.0 124.25 6.57648779452e-05 12.5557874325 29137
# value test：6.5764877945e-05
# keyname = d
# level = 600
# total elems and levels:21
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 950
# len:101441
# 40.0 124.25 -7.64008145779e-05 12.5557874325 29137
# value test：-7.6400814578e-05
# keyname = d
# level = 950
# total elems and levels:22
# ----------------------------------------------------------------------------------------------------
# ...
# value test：-7.8607635498e+00
# keyname = v
# level = 1000
# total elems and levels:101
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 1000
# len:101441
# 40.0 124.25 2.29761123657 12.5557874325 29137
# value test：2.2976112366e+00
# keyname = u
# level = 1000
# total elems and levels:102
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 10
# len:101441
# 40.0 124.25 -0.0136429667473 12.5557874325 29137
# value test：-1.3642966747e-02
# keyname = w
# level = 10
# total elems and levels:103
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 500
# len:101441
# 40.0 124.25 -11.4317626953 12.5557874325 29137
# value test：-1.1431762695e+01
# keyname = v
# level = 500
# total elems and levels:104
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 500
# len:101441
# 40.0 124.25 32.511428833 12.5557874325 29137
# value test：3.2511428833e+01
# keyname = u
# level = 500
# total elems and levels:105
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 70
# len:101441
# 40.0 124.25 18411.6484375 12.5557874325 29137
# value test：1.8411648438e+04
# keyname = gh
# level = 70
# total elems and levels:106
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 800
# len:101441
# 40.0 124.25 -9.93399047852 12.5557874325 29137
# value test：-9.9339904785e+00
# keyname = v
# level = 800
# total elems and levels:107
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 800
# len:101441
# 40.0 124.25 12.5587158203 12.5557874325 29137
# value test：1.2558715820e+01
# keyname = u
# level = 800
# total elems and levels:108
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 900
# len:101441
# 40.0 124.25 0.00125663960353 12.5557874325 29137
# value test：1.2566396035e-03
# keyname = q
# level = 900
# total elems and levels:109
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 100
# len:101441
# 40.0 124.25 5.47306442261 12.5557874325 29137
# value test：5.4730644226e+00
# keyname = r
# level = 100
# total elems and levels:110
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 950
# len:101441
# 40.0 124.25 603.723632812 12.5557874325 29137
# value test：6.0372363281e+02
# keyname = gh
# level = 950
# total elems and levels:111
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 50
# len:101441
# 40.0 124.25 0.00011112773791 12.5557874325 29137
# value test：1.1112773791e-04
# keyname = d
# level = 50
# total elems and levels:112
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 400
# len:101441
# 40.0 124.25 7148.3828125 12.5557874325 29137
# value test：7.1483828125e+03
# keyname = gh
# level = 400
# total elems and levels:113
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 500
# len:101441
# 40.0 124.25 0.00010121868678 12.5557874325 29137
# value test：1.0121868678e-04
# keyname = q
# level = 500
# total elems and levels:114
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 850
# len:101441
# 40.0 124.25 1493.43164062 12.5557874325 29137
# value test：1.4934316406e+03
# keyname = gh
# level = 850
# total elems and levels:115
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 70
# len:101441
# 40.0 124.25 2.77326971292 12.5557874325 29137
# value test：2.7732697129e+00
# keyname = r
# level = 70
# total elems and levels:116
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 100
# len:101441
# 40.0 124.25 3.26158442476e-06 12.5557874325 29137
# value test：3.2615844248e-06
# keyname = q
# level = 100
# total elems and levels:117
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 500
# len:101441
# 40.0 124.25 0.748672485352 12.5557874325 29137
# value test：7.4867248535e-01
# keyname = w
# level = 500
# total elems and levels:118
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 50
# len:101441
# 40.0 124.25 -0.00249636173248 12.5557874325 29137
# value test：-2.4963617325e-03
# keyname = w
# level = 50
# total elems and levels:119
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 900
# len:101441
# 40.0 124.25 29.1800880432 12.5557874325 29137
# value test：2.9180088043e+01
# keyname = r
# level = 900
# total elems and levels:120
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 100
# len:101441
# 40.0 124.25 212.068832397 12.5557874325 29137
# value test：2.1206883240e+02
# keyname = t
# level = 100
# total elems and levels:121
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 1000
# len:101441
# 40.0 124.25 276.232498169 12.5557874325 29137
# value test：2.7623249817e+02
# keyname = t
# level = 1000
# total elems and levels:122
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 250
# len:101441
# 40.0 124.25 0.248106002808 12.5557874325 29137
# value test：2.4810600281e-01
# keyname = w
# level = 250
# total elems and levels:123
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 1000
# len:101441
# 40.0 124.25 49.6281862259 12.5557874325 29137
# value test：4.9628186226e+01
# keyname = r
# level = 1000
# total elems and levels:124
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 500
# len:101441
# 40.0 124.25 12.0 12.5557874325 29137
# value test：1.2000000000e+01
# keyname = r
# level = 500
# total elems and levels:125
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 150
# len:101441
# 40.0 124.25 218.168167114 12.5557874325 29137
# value test：2.1816816711e+02
# keyname = t
# level = 150
# total elems and levels:126
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 10
# len:101441
# 40.0 124.25 2.95935933536e-06 12.5557874325 29137
# value test：2.9593593354e-06
# keyname = q
# level = 10
# total elems and levels:127
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 800
# len:101441
# 40.0 124.25 0.000689485202201 12.5557874325 29137
# value test：6.8948520220e-04
# keyname = q
# level = 800
# total elems and levels:128
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 400
# len:101441
# 40.0 124.25 11.5 12.5557874325 29137
# value test：1.1500000000e+01
# keyname = r
# level = 400
# total elems and levels:129
# ----------------------------------------------------------------------------------------------------
# keyname = sd
# level = 0
# len:4150080
# 39.875 124.125 0.0 5.13128153418 1155873
# value test：0.0000000000e+00
# keyname = sd
# level = 0
# total elems and levels:130
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 900
# len:101441
# 40.0 124.25 -0.429374694824 12.5557874325 29137
# value test：-4.2937469482e-01
# keyname = w
# level = 900
# total elems and levels:131
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 300
# len:101441
# 40.0 124.25 1.29931640625 12.5557874325 29137
# value test：1.2993164062e+00
# keyname = v
# level = 300
# total elems and levels:132
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 300
# len:101441
# 40.0 124.25 47.771774292 12.5557874325 29137
# value test：4.7771774292e+01
# keyname = u
# level = 300
# total elems and levels:133
# ----------------------------------------------------------------------------------------------------
# keyname = 2d
# level = 0
# len:4150080
# 39.875 124.125 267.908325195 5.13128153418 1155873
# value test：2.6790832520e+02
# keyname = 2d
# level = 0
# total elems and levels:134
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 70
# len:101441
# 40.0 124.25 214.361862183 12.5557874325 29137
# value test：2.1436186218e+02
# keyname = t
# level = 70
# total elems and levels:135
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 950
# len:101441
# 40.0 124.25 273.950057983 12.5557874325 29137
# value test：2.7395005798e+02
# keyname = t
# level = 950
# total elems and levels:136
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 300
# len:101441
# 40.0 124.25 1.25132501125e-05 12.5557874325 29137
# value test：1.2513250113e-05
# keyname = d
# level = 300
# total elems and levels:137
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 300
# len:101441
# 40.0 124.25 0.155961036682 12.5557874325 29137
# value test：1.5596103668e-01
# keyname = w
# level = 300
# total elems and levels:138
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 300
# len:101441
# 40.0 124.25 2.38611719396e-05 12.5557874325 29137
# value test：2.3861171940e-05
# keyname = q
# level = 300
# total elems and levels:139
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 925
# len:101441
# 40.0 124.25 817.704833984 12.5557874325 29137
# value test：8.1770483398e+02
# keyname = gh
# level = 925
# total elems and levels:140
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 1000
# len:101441
# 40.0 124.25 0.00237635965459 12.5557874325 29137
# value test：2.3763596546e-03
# keyname = q
# level = 1000
# total elems and levels:141
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 400
# len:101441
# 40.0 124.25 237.871383667 12.5557874325 29137
# value test：2.3787138367e+02
# keyname = t
# level = 400
# total elems and levels:142
# ----------------------------------------------------------------------------------------------------
# keyname = 2t
# level = 0
# len:4150080
# 39.875 124.125 279.318527222 5.13128153418 1155873
# value test：2.7931852722e+02
# keyname = 2t
# level = 0
# total elems and levels:143
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 20
# len:101441
# 40.0 124.25 26336.125 12.5557874325 29137
# value test：2.6336125000e+04
# keyname = gh
# level = 20
# total elems and levels:144
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 400
# len:101441
# 40.0 124.25 0.424209594727 12.5557874325 29137
# value test：4.2420959473e-01
# keyname = w
# level = 400
# total elems and levels:145
# ----------------------------------------------------------------------------------------------------
# keyname = msl
# level = 0
# len:4150080
# 39.875 124.125 102397.5625 5.13128153418 1155873
# value test：1.0239756250e+05
# keyname = msl
# level = 0
# total elems and levels:146
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 200
# len:101441
# 40.0 124.25 6.46112155914 12.5557874325 29137
# value test：6.4611215591e+00
# keyname = r
# level = 200
# total elems and levels:147
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 250
# len:101441
# 40.0 124.25 1.95291358978e-05 12.5557874325 29137
# value test：1.9529135898e-05
# keyname = d
# level = 250
# total elems and levels:148
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 925
# len:101441
# 40.0 124.25 273.687606812 12.5557874325 29137
# value test：2.7368760681e+02
# keyname = t
# level = 925
# total elems and levels:149
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 850
# len:101441
# 40.0 124.25 -10.6700439453 12.5557874325 29137
# value test：-1.0670043945e+01
# keyname = v
# level = 850
# total elems and levels:150
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 850
# len:101441
# 40.0 124.25 7.69515991211 12.5557874325 29137
# value test：7.6951599121e+00
# keyname = u
# level = 850
# total elems and levels:151
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 500
# len:101441
# 40.0 124.25 249.085723877 12.5557874325 29137
# value test：2.4908572388e+02
# keyname = t
# level = 500
# total elems and levels:152
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 10
# len:101441
# 40.0 124.25 -2.63952636719 12.5557874325 29137
# value test：-2.6395263672e+00
# keyname = v
# level = 10
# total elems and levels:153
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 10
# len:101441
# 40.0 124.25 20.4659881592 12.5557874325 29137
# value test：2.0465988159e+01
# keyname = u
# level = 10
# total elems and levels:154
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 950
# len:101441
# 40.0 124.25 0.00181941385381 12.5557874325 29137
# value test：1.8194138538e-03
# keyname = q
# level = 950
# total elems and levels:155
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 300
# len:101441
# 40.0 124.25 227.653182983 12.5557874325 29137
# value test：2.2765318298e+02
# keyname = t
# level = 300
# total elems and levels:156
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 150
# len:101441
# 40.0 124.25 13638.1289062 12.5557874325 29137
# value test：1.3638128906e+04
# keyname = gh
# level = 150
# total elems and levels:157
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 150
# len:101441
# 40.0 124.25 -4.16815746576e-05 12.5557874325 29137
# value test：-4.1681574658e-05
# keyname = d
# level = 150
# total elems and levels:158
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 500
# len:101441
# 40.0 124.25 1.37004535645e-05 12.5557874325 29137
# value test：1.3700453565e-05
# keyname = d
# level = 500
# total elems and levels:159
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 925
# len:101441
# 40.0 124.25 -14.0263824463 12.5557874325 29137
# value test：-1.4026382446e+01
# keyname = v
# level = 925
# total elems and levels:160
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 925
# len:101441
# 40.0 124.25 3.55819702148 12.5557874325 29137
# value test：3.5581970215e+00
# keyname = u
# level = 925
# total elems and levels:161
# ----------------------------------------------------------------------------------------------------
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
